# %%
import pandas as pd

print("Starting the script")

df = pd.read_csv('pas_refseq.csv', dtype={34:str, 35:str, 36:str})
# Out:
# Starting the script

# %%
df.head()
# Out:
#   #assembly_accession   bioproject     biosample         wgs_master  \
# 0     GCF_036600855.1  PRJNA224116  SAMN38772065  JBAFXD000000000.1
# 1     GCF_036600875.1  PRJNA224116  SAMN38772066  JBAFXC000000000.1
# 2     GCF_036600895.1  PRJNA224116  SAMN38772064  JBAFXE000000000.1
# 3     GCF_036600915.1  PRJNA224116  SAMN38772067  JBAFXF000000000.1
# 4     GCF_900128725.1  PRJNA224116  SAMEA4556317                 na
#
#   refseq_category  taxid  species_taxid             organism_name  \
# 0              na      7              7  Azorhizobium caulinodans
# 1              na      7              7  Azorhizobium caulinodans
# 2              na      7              7  Azorhizobium caulinodans
# 3              na      7              7  Azorhizobium caulinodans
# 4              na      9              9       Buchnera aphidicola
#
#     infraspecific_name isolate  ... replicon_count scaffold_count  \
# 0   strain=CNM20190194      na  ...              0            171
# ...

# %%
df = df[df["assembly_level"] != "Scaffold"]

# %%
df.head(10)
# Out:
#    #assembly_accession   bioproject     biosample         wgs_master  \
# 0      GCF_036600855.1  PRJNA224116  SAMN38772065  JBAFXD000000000.1
# 1      GCF_036600875.1  PRJNA224116  SAMN38772066  JBAFXC000000000.1
# 2      GCF_036600895.1  PRJNA224116  SAMN38772064  JBAFXE000000000.1
# 3      GCF_036600915.1  PRJNA224116  SAMN38772067  JBAFXF000000000.1
# 4      GCF_900128725.1  PRJNA224116  SAMEA4556317                 na
# 6      GCF_008244535.1  PRJNA224116  SAMN12634886     VTFL00000000.1
# 7      GCF_026418735.1  PRJNA224116  SAMN30305022  JAOAAT000000000.1
# 8      GCF_003854875.1  PRJNA224116  SAMN10058823                 na
# 10     GCF_019654935.1  PRJNA224116  SAMD00284622     BPEU00000000.1
# 11     GCF_019655395.1  PRJNA224116  SAMD00284635     BPFF00000000.1
#
#    refseq_category  taxid  species_taxid                 organism_name  \
# 0               na      7              7      Azorhizobium caulinodans
# ...

# %% [markdown]
# This is text

# %%
df = df[df["release_type"] != "Minor"]
df[8500:8510]
# Out:
#       #assembly_accession   bioproject     biosample      wgs_master  \
# 10873     GCF_002201255.1  PRJNA224116  SAMN07175298  NIIZ00000000.1
# 10874     GCF_002201295.1  PRJNA224116  SAMN07175294  NIJD00000000.1
# 10875     GCF_002201305.1  PRJNA224116  SAMN07175295  NIJC00000000.1
# 10876     GCF_002201325.1  PRJNA224116  SAMN07175302  NIIV00000000.1
# 10877     GCF_002201375.1  PRJNA224116  SAMN07175301  NIIW00000000.1
# 10878     GCF_002201385.1  PRJNA224116  SAMN07175300  NIIX00000000.1
# 10879     GCF_002201395.1  PRJNA224116  SAMN07175299  NIIY00000000.1
# 10880     GCF_002201405.1  PRJNA224116  SAMN07175296  NIJB00000000.1
# 10881     GCF_002201455.1  PRJNA224116  SAMN07175293  NIJE00000000.1
# 10882     GCF_002204155.1  PRJNA224116  SAMN06546651  MYFK00000000.1
#
#       refseq_category  taxid  species_taxid           organism_name  \
# 10873              na    287            287  Pseudomonas aeruginosa
# 10874              na    287            287  Pseudomonas aeruginosa
# ...

# %%
df[df["release_type"] == "Major"]
# Out:
#        #assembly_accession   bioproject     biosample         wgs_master  \
# 0          GCF_036600855.1  PRJNA224116  SAMN38772065  JBAFXD000000000.1
# 1          GCF_036600875.1  PRJNA224116  SAMN38772066  JBAFXC000000000.1
# 2          GCF_036600895.1  PRJNA224116  SAMN38772064  JBAFXE000000000.1
# 3          GCF_036600915.1  PRJNA224116  SAMN38772067  JBAFXF000000000.1
# 4          GCF_900128725.1  PRJNA224116  SAMEA4556317                 na
# ...                    ...          ...           ...                ...
# 387571     GCF_043945195.1  PRJNA224116  SAMN42146672  JBIMQK000000000.1
# 387572     GCF_043945155.1  PRJNA224116  SAMN42146674  JBIMQI000000000.1
# 387573     GCF_043945025.1  PRJNA224116  SAMN42146683  JBIMQB000000000.1
# 387574     GCF_019856515.1  PRJNA224116  SAMN20865098                 na
# 387575     GCF_019720755.1  PRJNA224116  SAMN20752402                 na
#
#        refseq_category    taxid  species_taxid  \
# ...

# %%
df = df.drop_duplicates(subset=["organism_name"], keep = "last")
df.head

# %%
df.to_csv("cleanedpas.csv")

# %% [markdown]
# Notebook on cleaning the data
